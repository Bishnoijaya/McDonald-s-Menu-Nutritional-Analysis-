# %% [markdown]
# # McDonald's Menu Nutritional Analysis

# %% [markdown]
# # Problem Statement
# McDonald's is a global fast-food chain known for its diverse menu offerings. As a data analyst, your task is to analyze the nutritional content of the menu items available at McDonald's outlets. This analysis will provide valuable insights into the calorie count and nutrition facts of various menu items.

# %% [markdown]
# # DATA

# %% [markdown]
#  ###### CATEGORY =  Category of the menu items
#  ###### Items = Items name displayed on menu
#  ###### Serving Size =  serving size of an item
#  ###### Calories = Calories count of an item
#  ###### Calories from fat = Calories count from the fat of an item
#  ###### Total Fat = Total Fat of an item
#  ###### Total Fat(% Daily Value) = Daily percentage value of Fat
#  ###### Satuarated Fat = Total Satuarated Fat in an item
#  ###### Satuarated Fat(% Daily Value) = Daily percentage value of Satuarated Fat
#  ###### Trans Fat = Total Trans Fat of an item
#  ###### Choloestrol = Total Cholestrol value in an item
#  ###### Choloestrol(% Daily Value) = Daily percentage value of  Cholestrol of an item
#  ###### Sodium = Total Sodium count in an item
#  ###### Sodium(% Daily Value) = Daily percentage value of Sodium of an item
#  ###### Carbohydrate = Total Carbohydrates  count in an item
#  ###### Carbohydrate(% Daily Value) = Daily percentage value of Carbohydrate of an item
#  ###### Dietar = Total Dietary fiber in an menu item
#  ###### Sugars = Totsl Sugars count in an item
#  ###### Protein = Total Protein in the menu Item
#  ###### Vitamin A(% Daily Value) = Daily percentage value of Vitamin A
#  ###### Vitamin c(% Daily Value) = Daily percentage value of Vitamin C
#  ###### Calcium(% Daily Value) = Daily percentage value of Calcium
#  ###### Iron(% Daily Value) = Daily percentage value of Vitamin A

# %% [markdown]
# # Contents

# %% [markdown]
# ### 1. import libraries
# ### 2. Data preparation
# ### 3. Understanding the Data
# ### 4. Missing Value handling
# ### 5. Data describe
# ### 6. Exploratory Data analysis
# ### 7. Outlier Treatment

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # Data Preparation

# %%
MCD=pd.read_csv(r"C:\Users\bishn\Downloads\Nutrical Dataset (1).csv")
MCD.sample()
# Out:
#          Category            Item  Serving Size  Calories  Calories from Fat  \
# 147  Coffee & Tea  Coffee (Large)  16 fl oz cup         0                  0
#
#      Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 147        0.0                          0            0.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 147                              0        0.0  ...              0
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# 147                              0              0
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 147                              0       0        0
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 147                          0                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 147                        0                     0
#
# [1 rows x 24 columns]

# %% [markdown]
# # Understanding of Data

# %%
MCD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
len(MCD)
# Out:
# 260

# %%
MCD.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
len(MCD.columns)
# Out:
# 24

# %% [markdown]
# # Missing value Handing

# %%
MCD.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %% [markdown]
#  #### There is no null value in this dataset so we can proceed with our data

# %% [markdown]
# # Data Describe

# %%
Max=MCD['Calories'].max()
Max
# Out:
# 1880

# %%
MCD['Calories'].min()
# Out:
# 0

# %%
MCD.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(12,5))
sns.histplot(x='Sugars',data=MCD,bins=12,kde=True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## most of the items have sugar level within the range (0-8)

# %%
# items contains vitamin A
High_vitaminA=MCD.sort_values('Vitamin A (% Daily Value)').tail(10)

plt.figure(figsize=(8,6))
sns.barplot(y='Item',x='Vitamin A (% Daily Value)',data=High_vitaminA,label='Vitamin A (% Daily Value)')
plt.show()

# %% [markdown]
# ### Premium Southwest Salad with Crispy Chicken has much more vitamin A

# %%
# Identifying which item under whhich category has more fat
max_fat=MCD.sort_values('Total Fat').tail(10)

plt.figure(figsize=(10,4))
sns.barplot(y='Item',x='Total Fat',data=max_fat,hue='Category')
plt.show()

# %% [markdown]
# ## So chicken McNuggets (40 Piece) has  fat as compared to others which comes under chicken& fish

# %%
# Identify which item has more protein 
max_protein=MCD.sort_values('Protein').tail(10)
plt.figure(figsize=(10,4))
sns.barplot(y='Item',x='Total Fat',data=max_protein)
plt.show()

# %% [markdown]
#  ## Item named Chicken McNuggets(40 piece) has highest protein value

# %%
# identifying which item has more carbohydrate
max_carb=MCD3.sort_values('Carbohydrates').tail(10)
plt.figure(figsize=(10,4))
sns.barplot(y='Item',x='Carbohydrates',data=max_carb)
plt.show()

# %% [markdown]
# ### Chocolate shake has heigest carbohydrate

# %%
 # identifying which item has more calories
max_calories=MCD3.sort_values('Calories').tail(10)
plt.figure(figsize=(10,4))
sns.barplot(y='Item',x='Calories',data=max_calories)
plt.show()

# %% [markdown]
# Chicken McNuggets(40 piece) has highest amout of calories

# %%
min_calories=MCD3.sort_values('Calories').head(10)
plt.figure(figsize=(10,4))
sns.barplot(y='Item',x='Calories',data=min_calories)
plt.show()

# %%
# Identify Protein of an food items
max_Protein=MCD3.sort_values('Protein').tail(10)
plt.figure(figsize=(10,4))
sns.barplot(y='Item',x='Protein',data=max_Protein)
plt.show()

# %% [markdown]
# ### Chicken McNuggets(40 piece) has highest amout of protein

# %%
# Identify fat of an food items
min_Fat=MCD3.sort_values('Total Fat').head(10)
plt.figure(figsize=(10,4))
sns.barplot(y='Item',x='Total Fat',data=min_Fat)
plt.show()

# %% [markdown]
# ## Distribution of different  nutritions

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of the visualization
sns.set(style="whitegrid")

# Create subplots
fig, axes = plt.subplots(4, 1, figsize=(10, 18))

# Total Fat
sns.histplot(MCD3['Total Fat'], bins=30, kde=True, ax=axes[0])
axes[0].set_title('Distribution of Total Fat')
axes[0].set_xlabel('Total Fat (g)')
axes[0].set_ylabel('Frequency')

# Protein
sns.histplot(MCD3['Protein'], bins=30, kde=True, ax=axes[1])
axes[1].set_title('Distribution of Protein')
axes[1].set_xlabel('Protein (g)')
axes[1].set_ylabel('Frequency')

# Carbohydrates
sns.histplot(MCD3['Carbohydrates'], bins=30, kde=True, ax=axes[2])
axes[2].set_title('Distribution of Carbohydrates')
axes[2].set_xlabel('Carbohydrates (g)')
axes[2].set_ylabel('Frequency')

#  Calories
sns.histplot(MCD3['Calories'], bins=30, kde=True, ax=axes[3])
axes[3].set_title('Distribution of calories')
axes[3].set_xlabel('Calories (g)')
axes[3].set_ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#  identifying trends of vitamin A category wise
plt.figure(figsize=(8,3))
sns.barplot(y='Category',x='Vitamin A (% Daily Value)',data=MCD)
plt.show()

# %% [markdown]
# ## "Salads are abundant in vitamin A, whereas beverages are an inadequate source vitamin A."

# %%
#  Identifying trends of Iron categorywise
plt.figure(figsize=(8,3))
sns.barplot(y='Category',x='Iron (% Daily Value)',data=MCD3)
# Out:
# <Axes: xlabel='Iron (% Daily Value)', ylabel='Category'>

# %% [markdown]
# ## Beef&Pork are rich source of iron and beverages are poor source of iron

# %%
plt.figure(figsize=(14,3))
sns.boxplot(y='Cholesterol',x='Category',data=MCD,hue='Category')
plt.legend(ncols=MCD['Category'].nunique()/3)
plt.show()

# %% [markdown]
# ### Heighest cal0ries count of an item

# %%
Higest_calories_item=MCD2.sort_values('Calories').tail(1)
Higest_calories_item['Item']
# Out:
# 82    Chicken McNuggets (40 piece)
# Name: Item, dtype: object

# %% [markdown]
# Chicken McNuggets(40 piece) has highest amout of calories

# %% [markdown]
# # lowest calories count of an item

# %%
lowest_calories_item=MCD2.sort_values(['Calories']).head(1)


lowest_calories_item['Item'],['Calories']
# Out:
# (136    Dasani Water Bottle
#  Name: Item, dtype: object,
#  ['Calories'])

# %% [markdown]
#  Dasani Water Bottle has lowest calories count

# %% [markdown]
# # Outlier treatment

# %%
col=MCD2.select_dtypes(exclude='object').columns
Q1 = MCD2[col].quantile(0.25)
Q3 = MCD2[col].quantile(0.75)
IQR = Q3 - Q1
MCD2= MCD2[~((MCD2[col] < (Q1 - 1.5*IQR))| (MCD2[col] > (Q3 + 1.5*IQR))).any(axis=1)]

# %%
len(MCD2)
# Out:
# 154

# %%
MCD3=pd.read_csv(r"C:\Users\bishn\Downloads\Nutrical Dataset (1).csv")
MCD3
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# # Determine the average nutritional content of popular menu categories.

# %%
numeric_MCD3 = MCD3.select_dtypes(include='number')

# %%
numeric_MCD3['Category'] = MCD3['Category']

# %%
Average_MCD3 = numeric_MCD3.groupby('Category').mean()
Average_MCD3
# Out:
#                       Calories  Calories from Fat  Total Fat  \
# Category
# Beef & Pork         494.000000         224.666667  24.866667
# Beverages           113.703704           0.740741   0.092593
# Breakfast           526.666667         248.928571  27.690476
# Chicken & Fish      552.962963         242.222222  26.962963
# Coffee & Tea        283.894737          71.105263   8.021053
# Desserts            222.142857          64.285714   7.357143
# Salads              270.000000         108.333333  11.750000
# Smoothies & Shakes  531.428571         127.678571  14.125000
# Snacks & Sides      245.769231          94.615385  10.538462
#
#                     Total Fat (% Daily Value)  Saturated Fat  \
# Category
# Beef & Pork                         38.600000      10.466667
# Beverages                            0.148148       0.055556
# Breakfast                           42.666667      10.654762
# Chicken & Fish                      41.333333       6.166667
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[487], line 1
# ----> 1 sns.heatmap(data=MCD3.select_dtypes(include='number').groupby('Category'), annot=True, cmap='YlGnBu')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# ...
